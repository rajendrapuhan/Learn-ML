# %%
# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# Wordcloud is installed and imported!

# %%
chat = open('C:/Users/rajen/OneDrive/Documents/chat.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
alice_wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
alice_wc.generate(chat)

# %%
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
# display the word cloud
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
stopwords.add('Hahaha')
stopwords.add('hai')
stopwords.add('ka')
stopwords.add('Ye')
stopwords.add('kya')
stopwords.add('na')
stopwords.add('se')
stopwords.add('tha')
stopwords.add('ta')
stopwords.add('nai')      
stopwords.add('Yaa')
stopwords.add('ho')
stopwords.add('raha')
stopwords.add('aur')
stopwords.add('Hahahaha')
stopwords.add('re')
stopwords.add('bhi')
stopwords.add('toh')

stopwords.add('ha')
stopwords.add('Ha')
stopwords.add('Haha')
stopwords.add('ki')
stopwords.add('Waaah')
stopwords.add('kr')
stopwords.add('nhi')

# %%
alice_wc = WordCloud(
    background_color='white',
    max_words=1000,
    stopwords=stopwords
)

# generate the word cloud
alice_wc.generate(chat)

# %%
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
